"https://www.ncbi.nlm.nih.gov/snp/rs5036",
"https://www.ncbi.nlm.nih.gov/snp/rs5036",
"https://www.ncbi.nlm.nih.gov/snp/rs820878",
"https://www.ncbi.nlm.nih.gov/snp/rs5036"
]

# %%
# First item on list for testing webscraper
r = requests.get(link_list[0] + "#clinical_significance")

# %%
# SNP that contains an allele frequency table
r = requests.get("https://www.ncbi.nlm.nih.gov/snp/rs397508736#frequency_tab")

# %%
text = r.text

# %%
# make the text human readable
formatted_text = text.replace('Iteration', '\nIteration')
print(formatted_text)
# Out:
# <!DOCTYPE html>
#
#
#
#
# <html lang="en" >
# <head >
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <!-- Mobile properties -->
#     <meta name="HandheldFriendly" content="True">
#     <meta name="MobileOptimized" content="320">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
#
#     <!-- Stylesheets -->
#
#     <link href="/snp/static/django_uswds/uswds/css/uswds.css" rel="stylesheet" />
#
#
#
#     <link rel="stylesheet" href="/snp/static/nwds/css/nwds.css" />
#     <link rel="stylesheet" href="/snp/static/nwds/css/header.css" />
#     <link rel="stylesheet" href="/snp/static/nwds/css/footer.css" />
#     <link rel="stylesheet" href="/snp/static/nwds/css/form.css" />
#
#
#
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>
#
#
#
#     <title>rs397508736 RefSNP Report - dbSNP - NCBI</title>
#
#
#
#   <!-- Favicons -->
# ...

# %%
# Parse the HTML content
soup = BeautifulSoup(text, 'html.parser')

# Find the table by its ID
table = soup.find('table', id='clinical_significance_datatable')

# Extract the rows from the table body
rows = table.find('tbody').find_all('tr')

# Extract the data from each row
table_data = []
for row in rows:
    cols = row.find_all('td')
    cols = [col.get_text(strip=True) for col in cols]
    table_data.append(cols)

# Print the extracted data
for entry in table_data:
    print(entry[1])
# Out:
# Cystic fibrosis
# CFTR-related disorders

# %%
# Parse the HTML content
soup = BeautifulSoup(text, 'html.parser')

# Find the <tr> tag with the class "par_row"
global_entry = soup.find('tr', class_='par_row')

# Extract the data from the columns
columns = global_entry.find_all('td')
data = [col.get_text(strip=True) for col in columns]

# Print the extracted data
print(data)
# Out:
# ['Total', 'Global', '10680', 'T=1.00000', 'C=0.00000', '1.0', '0.0', '0.0', 'N/A']

# %%
meta_data = []

# %%
for i, link in enumerate(link_list):
    # if i == 10:
    #     break

    # get disease name
    r = requests.get(link + "#clinical_significance")
    text = r.text
    # Parse the HTML content
    soup = BeautifulSoup(text, 'html.parser')
    # Find the table by its ID
    table = soup.find('table', id='clinical_significance_datatable')
    # Extract the rows from the table body
    rows = table.find('tbody').find_all('tr')

    # Extract the data from each row
    table_data = []
    for row in rows:
        cols = row.find_all('td')
        cols = [col.get_text(strip=True) for col in cols]
        table_data.append(cols)
    
    # Print the extracted data
    names = []
    for entry in table_data:
        print(entry[1])
        names.append(entry[1])
    
    # get number of publications
    publications_dt = soup.find('dt', text='Publications')
    publications_dd = publications_dt.find_next_sibling('dd')
    publication_count = publications_dd.get_text(strip=True).split()[0] + " citations"
    print(publication_count)

    # get reference and variant population percentage
    r = requests.get(link + "#frequency_tab")
    text = r.text
    soup = BeautifulSoup(text, 'html.parser')

    global_entry = soup.find('tr', class_='par_row')
    
    if global_entry != None:
        columns = global_entry.find_all('td')
        allele_frequency_data = [col.get_text(strip=True) for col in columns]

    else:
        allele_frequency_data = ["None" for i in range(5)]

    print(allele_frequency_data)
    meta_data.append([names, link + "#clinical_significance", allele_frequency_data[2], allele_frequency_data[3], allele_frequency_data[4]])
# Out:
# Lissencephaly due to LIS1 mutation
# 0 citations
# C:\Users\lukys\AppData\Local\Temp\ipykernel_27336\670308002.py:29: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   publications_dt = soup.find('dt', text='Publications')
# ['None', 'None', 'None', 'None', 'None']
# Catecholaminergic polymorphic ventricular tachycardia
# 0 citations
# ['None', 'None', 'None', 'None', 'None']
# Hereditary spastic paraplegia 4
# 0 citations
# ['None', 'None', 'None', 'None', 'None']
# not provided
# Fumarase deficiency
# 0 citations
# ['None', 'None', 'None', 'None', 'None']
# FG syndrome 1
# 0 citations
# ['None', 'None', 'None', 'None', 'None']
# Cerebellar ataxia,Demyelinating peripheral neuropathy
# 0 citations
# ['None', 'None', 'None', 'None', 'None']
# Systemic lupus erythematosus 17
# 0 citations
# ['None', 'None', 'None', 'None', 'None']
# Angelman syndrome-like,Developmental and epileptic encephalopathy, 2
# 0 citations
# ...

# %%
print(meta_data)
print(len(meta_data))
# Out:
# [[['Lissencephaly due to LIS1 mutation'], 'https://www.ncbi.nlm.nih.gov/snp/rs2151663957#clinical_significance', 'None', 'None', 'None'], [['Catecholaminergic polymorphic ventricular tachycardia'], 'https://www.ncbi.nlm.nih.gov/snp/rs2149388042#clinical_significance', 'None', 'None', 'None'], [['Hereditary spastic paraplegia 4'], 'https://www.ncbi.nlm.nih.gov/snp/rs2148759388#clinical_significance', 'None', 'None', 'None'], [['not provided', 'Fumarase deficiency'], 'https://www.ncbi.nlm.nih.gov/snp/rs2147911550#clinical_significance', 'None', 'None', 'None'], [['FG syndrome 1'], 'https://www.ncbi.nlm.nih.gov/snp/rs2147808505#clinical_significance', 'None', 'None', 'None'], [['Cerebellar ataxia,Demyelinating peripheral neuropathy'], 'https://www.ncbi.nlm.nih.gov/snp/rs2147404569#clinical_significance', 'None', 'None', 'None'], [['Systemic lupus erythematosus 17'], 'https://www.ncbi.nlm.nih.gov/snp/rs2147245558#clinical_significance', 'None', 'None', 'None'], [['Angelman syndrome-like,
# ...

# %%
# Fill cvs file with information
import csv

header = ["Disease Name", "Link", "Sample Size", "Ref Allele", "Alt Allele"]

with open('clinical_significance.csv', 'w', newline='') as file:
    writer = csv.writer(file)

    writer.writerow(header)
    for row in meta_data:
        sanitized_names = ''
        if len(row[0]) == 1:
            for name in row[0]:
                sanitized_names = name
        else:
            for name in row[0]:
                sanitized_names += name
                sanitized_names += ", "
        row_to_write = [sanitized_names, row[1], row[2], row[3], row[4]]
        writer.writerow(row_to_write)
